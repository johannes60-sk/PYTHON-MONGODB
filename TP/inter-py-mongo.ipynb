# %% [markdown]
# # Interrogation de MongoDB avec Python
#
# ### MT - HETIC
#
# ### MT 4 CTO ET TECHLEAD (2023-2024)
#
# 1. Présentation de MongoDB
# 1. Connection depuis Python et interrogation de données

# %% [markdown]
# ## Présentation de MongoDB
#
# > Base de données **NoSQL** de type *Document Store* (orienté document)
#
# Objectifs :
#
# - Gestion possible de gros volumes de données
# - Facilité de déploiement et d'utilsiation
# - Possibilité de faire de choses assez complexes
#
# Plus d'informations sur [leur site](http://www.mongodb.com/)

# %% [markdown]
# ### Modèle des données
#
# Principe de base : les données sont des `documents`
#
# - Stocké en *Binary JSON* (`BSON`)
# - Documents similaires rassemblés dans des `collections`
#     - plusieurs collections possibles dans une base de données
# - Pas de schéma des documents définis en amont
# 	- contrairement à un BD relationnel ou NoSQL de type *Column Store*
# - Les documents peuvent n'avoir aucun point commun entre eux
# - Un document contient (généralement) l'ensemble des informations
# 	- pas (ou très peu) de jointure à faire idéalement
# - BD respectant **CP** (dans le théorème *CAP*)
# 	- propriétés ACID au niveau d'un document

# %% [markdown]
# ### Format `JSON`
#
# - `JavaScript Object Notation`, créé en 2005
# - Format léger d'échange de données structurées (**littéral**)
# - Schéma des données non connu (contenu dans les données)
# - Basé sur deux notions :
# 	- collection de couples clé/valeur
# 	- liste de valeurs ordonnées
# - Structures possibles :
# 	- objet (couples clé/valeur) : `{ "nom": "einstein", "prenom": "albert" }`
# 	- tableau (collection de valeurs) : `[ 1, 5, 10]`
# 	- une valeur dans un objet ou dans un tableau peut être elle-même un littéral
# - Deux types atomiques (`string` et `number`) et trois constantes (`true`, `false`, `null`)
#
# Validation possible du JSON sur [jsonlint.com/](http://jsonlint.com/)

# %% [markdown]
# #### Exemple de `JSON`
#
# ```json
# {
#     "address": {
#         "building": "469",
#         "coord": [
#             -73.9617,
#             40.6629
#         ],
#         "street": "Flatbush Avenue",
#         "zipcode": "11225"
#     },
#     "borough": "Brooklyn",
#     "cuisine": "Hamburgers",
#     "grades": [
#         {
#             "date": "2014-12-30 01:00:00",
#             "grade": "A",
#             "score": 8
#         },
#         {
#             "date": "2014-07-01 02:00:00",
#             "grade": "B",
#             "score": 23
#         }
#     ],
#     "name": "Wendy'S",
#     "restaurant_id": "30112340"
# }
# ```

# %% [markdown]
# ### Compléments
#
# `BSON` : extension de `JSON`
#
# - Quelques types supplémentaires (identifiant spécifique, binaire, date, ...)
# - Distinction entier et réel
#
# **Schéma dynamique**
#
# - Documents variant très fortement entre eux, même dans une même collection
# - On parle de **self-describing documents**
# - Ajout très facile d'un nouvel élément pour un document, même si cet élément est inexistant pour les autres
# - Pas de `ALTER TABLE` ou de redesign de la base

# %% [markdown]
# ### Langage d'interrogation
#
# - Pas de SQL (bien évidemment), ni de langage proche
# - Définition d'un langage propre
#     - `find()` : pour tout ce qui est restriction et projection
#     - `aggregate()` : pour tout ce qui est calcul de variable, d'aggrégats et de manipulations diverses
#     - ...
# - Langage JavaScript dans la console, permettant plus que les accès aux données
# 	- définition de variables
# 	- boucles
# 	- ...

# %% [markdown]
# ## Interaction entre Python et MongoDB
#
# Utilisation du package [`pymongo`](https://docs.mongodb.com/drivers/pymongo/)
#
# ### Connexion à un serveur distant
#
# - Utilisation d'une URI spécifique, avec login et passeword intégrés
# - Si connexion serveur local, pas besoin de mettre de paramètre à la fonction `pymongo.MongoClient()`

# %%
import pymongo
URI = 'mongodb+srv://user:user@cluster0.8qh9zhe.mongodb.net/?retryWrites=true&w=majority'
client = pymongo.MongoClient(URI) # enlever le paramètre URI si connexion locale
db = client.sample_restaurants

# %% [markdown]
# ## Exemples sur `restaurants`
#
# Dans ce document, nous allons travailler sur une base des restaurants New-Yorkais.

# %% [markdown]
# Voici le premier document est présenté ci-dessous sur les plus de 25000 restaurants new-yorkais (base de test fournie par [Mongo](https://docs.mongodb.com/getting-started/shell/import-data/))
#
# ```json
# {
#         "_id" : ObjectId("58ac16d1a251358ee4ee87de"),
#         "address" : {
#                 "building" : "469",
#                 "coord" : [
#                         -73.961704,
#                         40.662942
#                 ],
#                 "street" : "Flatbush Avenue",
#                 "zipcode" : "11225"
#         },
#         "borough" : "Brooklyn",
#         "cuisine" : "Hamburgers",
#         "grades" : [
#                 {
#                         "date" : ISODate("2014-12-30T00:00:00Z"),
#                         "grade" : "A",
#                         "score" : 8
#                 },
#                 {
#                         "date" : ISODate("2014-07-01T00:00:00Z"),
#                         "grade" : "B",
#                         "score" : 23
#                 },
#                 {
#                         "date" : ISODate("2013-04-30T00:00:00Z"),
#                         "grade" : "A",
#                         "score" : 12
#                 },
#                 {
#                         "date" : ISODate("2012-05-08T00:00:00Z"),
#                         "grade" : "A",
#                         "score" : 12
#                 }
#         ],
#         "name" : "Wendy'S",
#         "restaurant_id" : "30112340"
# }
# ```

# %% [markdown]
# ### Document dans `python`
#
# Les données `JSON` sont similaires à un dictionnaire `python`. Pour récupérer le premier document, nous utilisons la fonction `find()` de l'objet créé `m`.

# %%
d = db.restaurants.find(limit = 1)
d

# %% [markdown]
# L'objet retourné est un **curseur**, et non le résultat. Nous avons celui-ci lorsque nous utilisons `d` dans une commande telle qu'une transformation en `list` par exemple. Une fois le résultat retourné (un seul élément ici), le curseur ne renvoie plus rien

# %%
list(d)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list(d)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File ~/.local/lib/python3.10/site-packages/pymongo/cursor.py:1155, in Cursor._refresh(self)
#    1152     return len(self.__data)
#    1154 if not self.__session:
# -> 1155     self.__session = self.__collection.database.client._ensure_session()
#    1157 if self.__id is None:  # Query
#    1158     if (self.__min or self.__max) and not self.__hint:
#
# File ~/.local/lib/python3.10/site-packages/pymongo/mongo_client.py:1823, in MongoClient._ensure_session(self, session)
#    1818     return session
#    1820 try:
#    1821     # Don't make implicit sessions causally consistent. Applications
#    1822     # should always opt-in.
# -> 1823     return self.__start_session(True, causal_consistency=False)
#    1824 except (ConfigurationError, InvalidOperation):
#    1825     # Sessions not supported.
#    1826     return None
#
# File ~/.local/lib/python3.10/site-packages/pymongo/mongo_client.py:1766, in MongoClient.__start_session(self, implicit, **kwargs)
#    1763 def __start_session(self, implicit: bool, **kwargs: Any) -> ClientSession:
#    1764     # Raises ConfigurationError if sessions are not supported.
#    1765     if implicit:
# -> 1766         self._topology._check_implicit_session_support()
#    1767         server_session: Union[_EmptyServerSession, _ServerSession] = _EmptyServerSession()
#    1768     else:
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:573, in Topology._check_implicit_session_support(self)
#     571 def _check_implicit_session_support(self) -> None:
#     572     with self._lock:
# --> 573         self._check_session_support()
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:589, in Topology._check_session_support(self)
#     585         self._select_servers_loop(
#     586             any_server_selector, self.get_server_selection_timeout(), None
#     587         )
#     588 elif not self._description.readable_servers:
# --> 589     self._select_servers_loop(
#     590         readable_server_selector, self.get_server_selection_timeout(), None
#     591     )
#     593 session_timeout = self._description.logical_session_timeout_minutes
#     594 if session_timeout is None:
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:259, in Topology._select_servers_loop(self, selector, timeout, address)
#     256 while not server_descriptions:
#     257     # No suitable servers.
#     258     if timeout == 0 or now > end_time:
# --> 259         raise ServerSelectionTimeoutError(
#     260             f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     261         )
#     263     self._ensure_opened()
#     264     self._request_check_all()
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-ldovdfe-shard-00-02.8qh9zhe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-ldovdfe-shard-00-01.8qh9zhe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-ldovdfe-shard-00-00.8qh9zhe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6582af76f4fd58c3caa9331f, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-ldovdfe-shard-00-00.8qh9zhe.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-ldovdfe-shard-00-00.8qh9zhe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-ldovdfe-shard-00-01.8qh9zhe.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-ldovdfe-shard-00-01.8qh9zhe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-ldovdfe-shard-00-02.8qh9zhe.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-ldovdfe-shard-00-02.8qh9zhe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %% [markdown]
# ### Dénombrement
#
# - Fonction `count_documents({})` pour dénombrer les documents
#     - le paramètre `{}` est à mettre obligatoirement
#     - nous verrons juste après à quoi il sert
# - Fonction `estimated_document_count()`  pour estimer le nombre de documents, à utiliser de préférence en cas de multiples serveurs et de données massives
#
# #### Tous les restaurants

# %%
db.restaurants.count_documents({})
# Out:
# 25359

# %%
db.restaurants.estimated_document_count()
# Out:
# 25359

# %% [markdown]
# #### Sélection de documents
#
# Pour sélectionner les documents, nous allons utiliser le paramètre dans la fonction `count_documents()` (ainsi que dans les fonctions `distinct()` et `find()` que nous verrons plus tard).
#
# - `{}` : tous les documents
# - `{ "champs": valeur }` : documents ayant cette valeur pour ce champs
# - `{ condition1, condition2 }` : documents remplissant la condition 1 **ET** la condition 2
# - `"champs.sous_champs"` : permet d'accéder donc à un sous-champs d'un champs (que celui-ci soit un littéral ou un tableau)
# - `{ "champs": { "$opérateur": expression }}` : utilisation d'opérateurs dans la recherche
#     - `$in` : comparaison à un ensemble de valeurs
#     - `$gt`, `$gte`, `$lt`, `$lte`, `$ne` : comparaison (resp. *greater than*, *greater than or equal*, *less than*, *less than or equal*, *not equal*)

# %% [markdown]
# #### Comptage de certains documents
#
# - Restaurants de *Brooklyn*

# %%
db.restaurants.count_documents({ "borough": "Brooklyn" })
# Out:
# 6086

# %% [markdown]
# - Restaurants de *Brooklyn* proposant de la cuisine française

# %%
db.restaurants.count_documents({ "borough": "Brooklyn", "cuisine": "French" })
# Out:
# 54

# %% [markdown]
# #### Comptage de certains documents (suite)
#
# - Restaurants de *Brooklyn* proposant de la cuisine française ou italienne

# %%
db.restaurants.count_documents({ "borough": "Brooklyn", "cuisine": { "$in": ["French", "Italian"]} })
# Out:
# 246

# %% [markdown]
# - Idem mais écrit plus lisiblement

# %%
db.restaurants.count_documents(
  { 
    "borough": "Brooklyn", 
    "cuisine": { "$in": ["French", "Italian"]}
  }
)
# Out:
# 246

# %% [markdown]
# #### Comptage de certains documents (suite)
#
# - Restaurants situés sur *Franklin Street*
#     - Notez l'accès au champs `street` du champs `address`

# %%
db.restaurants.count_documents(
  { 
    "address.street": "Franklin Street"
  }
)
# Out:
# 25

# %% [markdown]
# - Restaurants ayant eu un score de 0

# %%
db.restaurants.count_documents(
  { 
    "grades.score": 0
  }
)
# Out:
# 1246

# %% [markdown]
# #### Comptage de certains documents
#
# - Restaurants ayant eu un score inférieur à 5

# %%
db.restaurants.count_documents(
  { 
    "grades.score": { "$lte": 5 }
  }
)
# Out:
# 10650

# %% [markdown]
# ### Valeurs distinctes
#
# On peut aussi voir la liste des valeurs distinctes d'un attribut, avec la fonction `distinct()`.
#
# - Quartier (`borough`), pour tous les restaurants

# %%
db.restaurants.distinct(key = "borough")
# Out:
# ['Bronx', 'Brooklyn', 'Manhattan', 'Missing', 'Queens', 'Staten Island']

# %% [markdown]
# #### Valeurs distinctes (suite)
#
# - Cuisine pour les restaurants de *Brooklyn*

# %%
db.restaurants.distinct(
  key = "cuisine",
  query = { "borough": "Brooklyn" }
)
# Out:
# ['Afghan',
#  'African',
#  'American',
#  'Armenian',
#  'Asian',
#  'Australian',
#  'Bagels/Pretzels',
#  'Bakery',
#  'Bangladeshi',
#  'Barbecue',
#  'Bottled beverages, including water, sodas, juices, etc.',
#  'Brazilian',
#  'Café/Coffee/Tea',
#  'Cajun',
#  'Caribbean',
#  'Chicken',
#  'Chilean',
#  'Chinese',
#  'Chinese/Cuban',
#  'Chinese/Japanese',
#  'Continental',
#  'Creole',
#  'Creole/Cajun',
#  'Czech',
#  'Delicatessen',
#  'Donuts',
#  'Eastern European',
#  'Egyptian',
#  'English',
#  'Ethiopian',
#  'Filipino',
#  'French',
#  'Fruits/Vegetables',
#  'German',
#  'Greek',
#  'Hamburgers',
#  'Hawaiian',
#  'Hotdogs',
#  'Hotdogs/Pretzels',
#  'Ice Cream, Gelato, Yogurt, Ices',
#  'Indian',
#  'Indonesian',
#  'Irish',
#  'Italian',
#  'Japanese',
#  'Jewish/Kosher',
#  'Juice, Smoothies, Fruit Salads',
#  'Korean',
#  'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'Mediterranean',
#  'Mexican',
#  'Middle Eastern',
#  'Moroccan',
#  'Not Listed/Not Applicable',
#  'Nuts/Confectionary',
#  'Other',
#  'Pakistani',
#  'Pancakes/Waffles',
#  'Peruvian',
#  'Pizza',
#  'Pizza/Italian',
#  'Polish',
#  'Portuguese',
#  'Russian',
#  'Salads',
#  'Sandwiches',
#  'Sandwiches/Salads/Mixed Buffet',
#  'Scandinavian',
#  'Seafood',
#  'Soul Food',
#  'Soups & Sandwiches',
#  'Southwestern',
#  'Spanish',
#  'Steak',
#  'Tapas',
#  'Tex-Mex',
#  'Thai',
#  'Turkish',
#  'Vegetarian',
#  'Vietnamese/Cambodian/Malaysia']

# %% [markdown]
# #### Valeurs distinctes (suite)
#
# - Grade des restaurants de *Brooklyn*

# %%
db.restaurants.distinct(
  key = "grades.grade",
  query = { "borough": "Brooklyn" }
)
# Out:
# ['A', 'B', 'C', 'Not Yet Graded', 'P', 'Z']

# %% [markdown]
# ### Restriction et Projection
#
# - Fonction `find()` pour réaliser les *restrictions* et *projections*
# - Plusieurs paramètres :
#     - Restriction (quels documents prendre) : même format que précédemment
#     - Projection (quels champs afficher)
#     - `limit` pour n'avoir que les $n$ premiers documents
#     - `sort` pour effectuer un tri des documents
# - Renvoie un curseur, qu'il faut donc gérer pour avoir le résultat
# - Transformation en `DataFrame` (du module `pandas`)
#     - Format pas forcément idéal pour certains champs

# %% [markdown]
# #### Sélection de champs à afficher ou non
#
# Dans la fonction `find()`, pour choisir les champs à afficher, le deuxième paramètre permet de faire une projection avec les critères suivants :
#
# - sans précision, l'identifiant interne est toujours affiché (`_id`)
# - `{ "champs": 1 }` : champs à afficher
# - `{ "champs": 0 }` : champs à ne pas afficher
# - Pas de mélange des 2 sauf pour l'identifiant interne à Mongo (`_id`)
#     - `{ "_id": 0, "champs": 1, ...}`

# %% [markdown]
# #### Tri et limite
#
# Toujours dans la fonction `find()`, il est possible de faire le tri des documents, avec le paramètre `sort` qui prend un tuple composé de 1 ou plusieurs tuples indiquant les critères de tri
#
# - `( "champs", 1 )` : tri croissant
# - `( "champs", -1 )` : tri décroissant
# - plusieurs critères de tri possibles (dans les 2 sens)
#
# Dans ces fonctions, on peut aussi limiter l'exploration à une partie, avec les paramètres suivant :
#
# - `limit` : restreint le nombre de résultats fournis
# - `skip` : ne considère pas les *n* premiers documents

# %% [markdown]
# #### Récupération des 5 premiers documents
#
# Notez le contenu des colonnes `address` et `grades`.

# %%
import pandas
pandas.DataFrame(db.restaurants.find(limit = 5))
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f4292a
# 1  5eb3d668b31de5d588f4292b
# 2  5eb3d668b31de5d588f4292c
# 3  5eb3d668b31de5d588f4292d
# 4  5eb3d668b31de5d588f4292e
#
#                                              address        borough  \
# 0  {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1  {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 2  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 3  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 4  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
#
#          cuisine                                             grades  \
# 0       American  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 1   Delicatessen  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
# 2  Jewish/Kosher  [{'date': 2014-10-06 00:00:00, 'grade': 'A', '...
# 3     Hamburgers  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 4         Bakery  [{'date': 2014-03-03 00:00:00, 'grade': 'A', '...
#
#                     name restaurant_id
# 0        Riviera Caterer      40356018
# 1     Wilken'S Fine Food      40356483
# 2          Kosher Island      40356442
# 3                Wendy'S      30112340
# 4  Morris Park Bake Shop      30075445

# %% [markdown]
# #### Récupération de documents (suite)
#
# - Restaurants *Shake Shack* (uniquement les attributs `"street"` et `"borough"`)

# %%
c = db.restaurants.find({ "name": "Shake Shack" }, { "address.street": 1, "borough": 1 })
pandas.DataFrame(c)
# Out:
#                          _id                                  address  \
# 0   5eb3d668b31de5d588f44aff            {'street': 'Columbus Avenue'}
# 1   5eb3d669b31de5d588f454fa           {'street': 'West   44 Street'}
# 2   5eb3d669b31de5d588f45512           {'street': 'East   86 Street'}
# 3   5eb3d669b31de5d588f45cc3           {'street': 'North End Avenue'}
# 4   5eb3d669b31de5d588f45e0d              {'street': 'Fulton Street'}
# 5   5eb3d669b31de5d588f472dd  {'street': 'Jfk International Airport'}
# 6   5eb3d669b31de5d588f47788     {'street': 'Grand Central Terminal'}
# 7   5eb3d669b31de5d588f4780c  {'street': 'Jfk International Airport'}
# 8   5eb3d669b31de5d588f48007          {'street': 'Old Fulton Street'}
# 9   5eb3d669b31de5d588f48009            {'street': 'Flatbush Avenue'}
# 10  5eb3d669b31de5d588f487e0                    {'street': '3Rd Ave'}
#
#       borough
# 0   Manhattan
# 1   Manhattan
# 2   Manhattan
# 3   Manhattan
# 4    Brooklyn
# 5      Queens
# 6   Manhattan
# 7      Queens
# 8    Brooklyn
# 9    Brooklyn
# 10  Manhattan

# %% [markdown]
# #### Récupération de documents (suite)
#
#
# - Idem sans l'identifiant interne

# %%
c = db.restaurants.find(
    { "name": "Shake Shack" }, 
    { "_id": 0, "address.street": 1, "borough": 1 }
)
pandas.DataFrame(c)
# Out:
#                                     address    borough
# 0             {'street': 'Columbus Avenue'}  Manhattan
# 1            {'street': 'West   44 Street'}  Manhattan
# 2            {'street': 'East   86 Street'}  Manhattan
# 3            {'street': 'North End Avenue'}  Manhattan
# 4               {'street': 'Fulton Street'}   Brooklyn
# 5   {'street': 'Jfk International Airport'}     Queens
# 6      {'street': 'Grand Central Terminal'}  Manhattan
# 7   {'street': 'Jfk International Airport'}     Queens
# 8           {'street': 'Old Fulton Street'}   Brooklyn
# 9             {'street': 'Flatbush Avenue'}   Brooklyn
# 10                    {'street': '3Rd Ave'}  Manhattan

# %% [markdown]
# #### Récupération de documents (suite)
#
#
# - 5 premiers restaurants du quartier *Queens*, avec une note A et un score supérieur à 50 (on affiche le nom et la rue du restaurant

# %%
c = db.restaurants.find(
    {"borough": "Queens", "grades.score": { "$gte":  50}},
    {"_id": 0, "name": 1, "grades.score": 1, "address.street": 1},
    limit = 5
)
pandas.DataFrame(c)
# Out:
#                                   address  \
# 0  {'street': 'Horace Harding Boulevard'}
# 1            {'street': 'Bell Boulevard'}
# 2  {'street': 'Rockaway Beach Boulevard'}
# 3                  {'street': 'Broadway'}
# 4       {'street': 'Woodhaven Boulevard'}
#
#                                               grades                name
# 0  [{'score': 12}, {'score': 4}, {'score': 11}, {...     Richer'S Bakery
# 1  [{'score': 52}, {'score': 12}, {'score': 22}, ...    Tequilla Sunrise
# 2  [{'score': 10}, {'score': 2}, {'score': 10}, {...  Rockaway Beach Inn
# 3  [{'score': 13}, {'score': 13}, {'score': 13}, ...       Alfonso'S Bar
# 4  [{'score': 2}, {'score': 64}, {'score': 9}, {'...             Pio Pio

# %% [markdown]
# #### Récupération de documents (suite)
#
#
# - Restaurants *Shake Shack* dans différents quartiers (*Queens* et *Brooklyn*)

# %%
c = db.restaurants.find(
    {"name": "Shake Shack", "borough": {"$in": ["Queens", "Brooklyn"]}}, 
    {"_id": 0, "address.street": 1, "borough": 1}
)
pandas.DataFrame(c)
# Out:
#                                    address   borough
# 0              {'street': 'Fulton Street'}  Brooklyn
# 1  {'street': 'Jfk International Airport'}    Queens
# 2  {'street': 'Jfk International Airport'}    Queens
# 3          {'street': 'Old Fulton Street'}  Brooklyn
# 4            {'street': 'Flatbush Avenue'}  Brooklyn

# %% [markdown]
# #### Récupération de documents (suite)
#
#
# - Restaurants du Queens ayant une note supérieure à 50, mais trié par ordre décroissant de noms de rue, et ordre croissant de noms de restaurants

# %%
c = db.restaurants.find(
    {"borough": "Queens", "grades.score": { "$gt":  50}},
    {"_id": 0, "name": 1, "address.street": 1},
    sort = (("address.street", -1), ("name", 1))
)
pandas.DataFrame(c)
# Out:
#                               address                       name
# 0       {'street': 'Woodward Avenue'}   Sabores Restaurant & Bar
# 1       {'street': 'Woodside Avenue'}                Salza Pizza
# 2       {'street': 'Woodside Avenue'}              Spicy Shallot
# 3   {'street': 'Woodhaven Boulevard'}               Fresh To You
# 4   {'street': 'Woodhaven Boulevard'}                    Pio Pio
# ..                                ...                        ...
# 73            {'street': '30 Avenue'}  Queens Comfort Restaurant
# 74            {'street': '20 Avenue'}     Cafeteria (Usps Bldng)
# 75           {'street': '153 Avenue'}               Tuscany Deli
# 76           {'street': '131 Street'}      Spa Castle/Juice Farm
# 77           {'street': '102 Street'}               Tacos Mexico
#
# [78 rows x 2 columns]

# %% [markdown]
# ### Aggrégation
#
# Cette fonction va prendre en paramètre un `pipeline` : tableau composé d'une suite d'opérations
#
# | Fonction       | Opération |
# |:-|:-|
# | `$limit`       | restriction à un petit nombre de documents (très utiles pour tester son calcul) |
# | `$sort`        | tri sur les documents |
# | `$match`       | restriction sur les documents à utiliser |
# | `$unwind`      | séparation d'un document en plusieurs sur la base d'un tableau |
# | `$addFields`   | ajout d'un champs dans les documents |
# | `$project`     | redéfinition des documents |
# | `$group`       | regroupements et calculs d'aggégrats |
# | `$sortByCount` | regroupement, calcul de dénombrement et tri déccroissant en une opération |
# | `$lookup`      | jointure avec une autre collection |
# | ...            | |

# %% [markdown]
# #### Syntaxe des opérations dans le `pipeline`
#
# Les opérations se font dans l'ordre d'écriture, et le même opérateur peut donc apparaître plusieurs fois
#
# - `$limit` : un entier
# - `$sort` : identique à celle du paramètre `sort` de la fonction `find()`
# - `$match` : identique à celle du paramètre `query` des autres fonctions
# - `$unwind` : nom du tableau servant de base pour le découpage (précédé d'un `$`)
#     - un document avec un tableau à *n* éléments deviendra *n* documents avec chacun un des éléments du tableau en lieu et place de celui-ci
# - `$sortByCount` : nom du champs sur lequel on veut le dénombrement et le tri décroissant selon le résultat

# %% [markdown]
# #### Syntaxe des opérations dans le `pipeline`
#
# `$project` : redéfinition des documents
#
# - `{ "champs" : 1 }` : conservation du champs (0 si suppression - idem que dans `fields`, pas de mélange sauf pour `_id`)
# - `{ "champs": { "$opérateur" : expression }}` : permet de définir un nouveau champs
# - `{ "nouveau_champs": "$ancien_champs" }` : renommage d'un champs
#
# Quelques opérateurs utiles pour la projection (plus d'info [ici](https://docs.mongodb.com/manual/reference/operator/aggregation/))
#
# - `$arrayElemAt` : élément d'un tableau
# - `$first` et `$last` : premier ou dernier élément du tableau
# - `$size` : taille d'un tableau
# - `$substr` : sous-chaîne de caractères
# - `$cond` : permet de faire une condition (genre de *if then else*)
# - ...

# %% [markdown]
# #### Syntaxe des opérations dans le `pipeline`
#
# `$group` : calcul d'agrégats
#
# - `_id` : déclaration du critère de regroupement
#     - chaîne de caractères : pas de regroupement (tous les documents)
#     - `$champs` : regroupement selon ce champs
#     - `{ "a1": "$champs1", ... }` : regroupement multiple (avec modification des valeurs possible)
# - Calculs d'agrégats à faire :
#     - `$sum` : somme (soit de valeur fixe - 1 pour faire un décompte donc, soit d'un champs spécifique)
#     - `$avg, $min, $max`
#     - `$addToSet` : regroupement des valeurs distinctes d'un champs dans un tableau
#     - `$push` : aggrégation de champs dans un tableau

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
# - Limite aux 5 premiers restaurants

# %%
c = db.restaurants.aggregate(
    [
        {"$limit": 10 }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f4292a
# 1  5eb3d668b31de5d588f4292b
# 2  5eb3d668b31de5d588f4292c
# 3  5eb3d668b31de5d588f4292d
# 4  5eb3d668b31de5d588f4292e
# 5  5eb3d668b31de5d588f4292f
# 6  5eb3d668b31de5d588f42930
# 7  5eb3d668b31de5d588f42931
# 8  5eb3d668b31de5d588f42932
# 9  5eb3d668b31de5d588f42933
#
#                                              address        borough  \
# 0  {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1  {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 2  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 3  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 4  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 5  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 6  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 7  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 8  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 9  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
#
#                            cuisine  \
# 0                         American
# 1                     Delicatessen
# 2                    Jewish/Kosher
# 3                       Hamburgers
# 4                           Bakery
# 5                    Jewish/Kosher
# 6                         American
# 7                         American
# 8  Ice Cream, Gelato, Yogurt, Ices
# 9                         American
#
#                                               grades  \
# 0  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 1  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
# 2  [{'date': 2014-10-06 00:00:00, 'grade': 'A', '...
# 3  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 4  [{'date': 2014-03-03 00:00:00, 'grade': 'A', '...
# 5  [{'date': 2014-11-24 00:00:00, 'grade': 'Z', '...
# 6  [{'date': 2014-11-15 00:00:00, 'grade': 'Z', '...
# 7  [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 8  [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 9  [{'date': 2014-05-28 00:00:00, 'grade': 'A', '...
#
#                           name restaurant_id
# 0              Riviera Caterer      40356018
# 1           Wilken'S Fine Food      40356483
# 2                Kosher Island      40356442
# 3                      Wendy'S      30112340
# 4        Morris Park Bake Shop      30075445
# 5           Tov Kosher Kitchen      40356068
# 6      Brunos On The Boulevard      40356151
# 7              Regina Caterers      40356649
# 8  Taste The Tropics Ice Cream      40356731
# 9                    Wild Asia      40357217

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Idem avec tri sur le nom du restaurant

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$sort": { "name": 1 }}
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f42930
# 1  5eb3d668b31de5d588f4292c
# 2  5eb3d668b31de5d588f4292e
# 3  5eb3d668b31de5d588f42931
# 4  5eb3d668b31de5d588f4292a
# 5  5eb3d668b31de5d588f42932
# 6  5eb3d668b31de5d588f4292f
# 7  5eb3d668b31de5d588f4292d
# 8  5eb3d668b31de5d588f42933
# 9  5eb3d668b31de5d588f4292b
#
#                                              address        borough  \
# 0  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 1  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 2  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 3  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 4  {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 5  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 6  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 7  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 8  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
# 9  {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
#
#                            cuisine  \
# 0                         American
# 1                    Jewish/Kosher
# 2                           Bakery
# 3                         American
# 4                         American
# 5  Ice Cream, Gelato, Yogurt, Ices
# 6                    Jewish/Kosher
# 7                       Hamburgers
# 8                         American
# 9                     Delicatessen
#
#                                               grades  \
# 0  [{'date': 2014-11-15 00:00:00, 'grade': 'Z', '...
# 1  [{'date': 2014-10-06 00:00:00, 'grade': 'A', '...
# 2  [{'date': 2014-03-03 00:00:00, 'grade': 'A', '...
# 3  [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 4  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 5  [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 6  [{'date': 2014-11-24 00:00:00, 'grade': 'Z', '...
# 7  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 8  [{'date': 2014-05-28 00:00:00, 'grade': 'A', '...
# 9  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
#
#                           name restaurant_id
# 0      Brunos On The Boulevard      40356151
# 1                Kosher Island      40356442
# 2        Morris Park Bake Shop      30075445
# 3              Regina Caterers      40356649
# 4              Riviera Caterer      40356018
# 5  Taste The Tropics Ice Cream      40356731
# 6           Tov Kosher Kitchen      40356068
# 7                      Wendy'S      30112340
# 8                    Wild Asia      40357217
# 9           Wilken'S Fine Food      40356483

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Idem en se restreignant à *Brooklyn*
#     - Notez que nous obtenons uniquement 5 restaurants au final

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$sort": { "name": 1 }},
        { "$match": { "borough": "Brooklyn" }}
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f42931
# 1  5eb3d668b31de5d588f4292a
# 2  5eb3d668b31de5d588f42932
# 3  5eb3d668b31de5d588f4292d
# 4  5eb3d668b31de5d588f4292b
#
#                                              address   borough  \
# 0  {'building': '6409', 'coord': [-74.00528899999...  Brooklyn
# 1  {'building': '2780', 'coord': [-73.98241999999...  Brooklyn
# 2  {'building': '1839', 'coord': [-73.9482609, 40...  Brooklyn
# 3  {'building': '469', 'coord': [-73.961704, 40.6...  Brooklyn
# 4  {'building': '7114', 'coord': [-73.9068506, 40...  Brooklyn
#
#                            cuisine  \
# 0                         American
# 1                         American
# 2  Ice Cream, Gelato, Yogurt, Ices
# 3                       Hamburgers
# 4                     Delicatessen
#
#                                               grades  \
# 0  [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 1  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 2  [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 3  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 4  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
#
#                           name restaurant_id
# 0              Regina Caterers      40356649
# 1              Riviera Caterer      40356018
# 2  Taste The Tropics Ice Cream      40356731
# 3                      Wendy'S      30112340
# 4           Wilken'S Fine Food      40356483

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Mêmes opérations mais avec la restriction en amont de la limite
#     - Nous avons ici les 10 premiers restaurants de *Brooklyn* donc

# %%
c = db.restaurants.aggregate(
    [
        { "$match": { "borough": "Brooklyn" }},
        { "$limit": 10 },
        { "$sort": { "name": 1 }}
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f42934
# 1  5eb3d668b31de5d588f4293a
# 2  5eb3d668b31de5d588f42936
# 3  5eb3d668b31de5d588f4293b
# 4  5eb3d668b31de5d588f42931
# 5  5eb3d668b31de5d588f4292a
# 6  5eb3d668b31de5d588f42935
# 7  5eb3d668b31de5d588f42932
# 8  5eb3d668b31de5d588f4292d
# 9  5eb3d668b31de5d588f4292b
#
#                                              address   borough  \
# 0  {'building': '7715', 'coord': [-73.9973325, 40...  Brooklyn
# 1  {'building': '203', 'coord': [-73.978220400000...  Brooklyn
# 2  {'building': '1269', 'coord': [-73.871194, 40....  Brooklyn
# 3  {'building': '6909', 'coord': [-74.0259567, 40...  Brooklyn
# 4  {'building': '6409', 'coord': [-74.00528899999...  Brooklyn
# 5  {'building': '2780', 'coord': [-73.98241999999...  Brooklyn
# 6  {'building': '705', 'coord': [-73.9653967, 40....  Brooklyn
# 7  {'building': '1839', 'coord': [-73.9482609, 40...  Brooklyn
# 8  {'building': '469', 'coord': [-73.961704, 40.6...  Brooklyn
# 9  {'building': '7114', 'coord': [-73.9068506, 40...  Brooklyn
#
#                            cuisine  \
# 0                         American
# 1  Ice Cream, Gelato, Yogurt, Ices
# 2                          Chinese
# 3                     Delicatessen
# 4                         American
# 5                         American
# 6                    Jewish/Kosher
# 7  Ice Cream, Gelato, Yogurt, Ices
# 8                       Hamburgers
# 9                     Delicatessen
#
#                                               grades  \
# 0  [{'date': 2014-04-16 00:00:00, 'grade': 'A', '...
# 1  [{'date': 2014-02-10 00:00:00, 'grade': 'A', '...
# 2  [{'date': 2014-09-16 00:00:00, 'grade': 'B', '...
# 3  [{'date': 2014-08-21 00:00:00, 'grade': 'A', '...
# 4  [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 5  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 6  [{'date': 2014-11-10 00:00:00, 'grade': 'A', '...
# 7  [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 8  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 9  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
#
#                           name restaurant_id
# 0       C & C Catering Service      40357437
# 1             Carvel Ice Cream      40360076
# 2              May May Kitchen      40358429
# 3            Nordic Delicacies      40361390
# 4              Regina Caterers      40356649
# 5              Riviera Caterer      40356018
# 6                  Seuda Foods      40360045
# 7  Taste The Tropics Ice Cream      40356731
# 8                      Wendy'S      30112340
# 9           Wilken'S Fine Food      40356483

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Séparation des 5 premiers restaurants sur la base des évaluations (`grades`)
#     - Chaque ligne correspond maintenant a une évaluation pour un restaurant

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 5 },
        { "$unwind": "$grades" }
    ]
)
pandas.DataFrame(c)
# Out:
#                          _id  \
# 0   5eb3d668b31de5d588f4292a
# 1   5eb3d668b31de5d588f4292a
# 2   5eb3d668b31de5d588f4292a
# 3   5eb3d668b31de5d588f4292a
# 4   5eb3d668b31de5d588f4292b
# 5   5eb3d668b31de5d588f4292b
# 6   5eb3d668b31de5d588f4292b
# 7   5eb3d668b31de5d588f4292b
# 8   5eb3d668b31de5d588f4292b
# 9   5eb3d668b31de5d588f4292b
# 10  5eb3d668b31de5d588f4292c
# 11  5eb3d668b31de5d588f4292c
# 12  5eb3d668b31de5d588f4292c
# 13  5eb3d668b31de5d588f4292c
# 14  5eb3d668b31de5d588f4292d
# 15  5eb3d668b31de5d588f4292d
# 16  5eb3d668b31de5d588f4292d
# 17  5eb3d668b31de5d588f4292d
# 18  5eb3d668b31de5d588f4292e
# 19  5eb3d668b31de5d588f4292e
# 20  5eb3d668b31de5d588f4292e
# 21  5eb3d668b31de5d588f4292e
# 22  5eb3d668b31de5d588f4292e
#
#                                               address        borough  \
# 0   {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1   {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 2   {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 3   {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 4   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 5   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 6   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 7   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 8   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 9   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 10  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 11  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 12  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 13  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 14  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 15  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 16  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 17  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 18  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 19  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 20  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 21  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 22  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
#
#           cuisine                                             grades  \
# 0        American  {'date': 2014-06-10 00:00:00, 'grade': 'A', 's...
# 1        American  {'date': 2013-06-05 00:00:00, 'grade': 'A', 's...
# 2        American  {'date': 2012-04-13 00:00:00, 'grade': 'A', 's...
# 3        American  {'date': 2011-10-12 00:00:00, 'grade': 'A', 's...
# 4    Delicatessen  {'date': 2014-05-29 00:00:00, 'grade': 'A', 's...
# 5    Delicatessen  {'date': 2014-01-14 00:00:00, 'grade': 'A', 's...
# 6    Delicatessen  {'date': 2013-08-03 00:00:00, 'grade': 'A', 's...
# 7    Delicatessen  {'date': 2012-07-18 00:00:00, 'grade': 'A', 's...
# 8    Delicatessen  {'date': 2012-03-09 00:00:00, 'grade': 'A', 's...
# 9    Delicatessen  {'date': 2011-10-14 00:00:00, 'grade': 'A', 's...
# 10  Jewish/Kosher  {'date': 2014-10-06 00:00:00, 'grade': 'A', 's...
# 11  Jewish/Kosher  {'date': 2014-05-20 00:00:00, 'grade': 'A', 's...
# 12  Jewish/Kosher  {'date': 2013-04-04 00:00:00, 'grade': 'A', 's...
# 13  Jewish/Kosher  {'date': 2012-01-24 00:00:00, 'grade': 'A', 's...
# 14     Hamburgers  {'date': 2014-12-30 00:00:00, 'grade': 'A', 's...
# 15     Hamburgers  {'date': 2014-07-01 00:00:00, 'grade': 'B', 's...
# 16     Hamburgers  {'date': 2013-04-30 00:00:00, 'grade': 'A', 's...
# 17     Hamburgers  {'date': 2012-05-08 00:00:00, 'grade': 'A', 's...
# 18         Bakery  {'date': 2014-03-03 00:00:00, 'grade': 'A', 's...
# 19         Bakery  {'date': 2013-09-11 00:00:00, 'grade': 'A', 's...
# 20         Bakery  {'date': 2013-01-24 00:00:00, 'grade': 'A', 's...
# 21         Bakery  {'date': 2011-11-23 00:00:00, 'grade': 'A', 's...
# 22         Bakery  {'date': 2011-03-10 00:00:00, 'grade': 'B', 's...
#
#                      name restaurant_id
# 0         Riviera Caterer      40356018
# 1         Riviera Caterer      40356018
# 2         Riviera Caterer      40356018
# 3         Riviera Caterer      40356018
# 4      Wilken'S Fine Food      40356483
# 5      Wilken'S Fine Food      40356483
# 6      Wilken'S Fine Food      40356483
# 7      Wilken'S Fine Food      40356483
# 8      Wilken'S Fine Food      40356483
# 9      Wilken'S Fine Food      40356483
# 10          Kosher Island      40356442
# 11          Kosher Island      40356442
# 12          Kosher Island      40356442
# 13          Kosher Island      40356442
# 14                Wendy'S      30112340
# 15                Wendy'S      30112340
# 16                Wendy'S      30112340
# 17                Wendy'S      30112340
# 18  Morris Park Bake Shop      30075445
# 19  Morris Park Bake Shop      30075445
# 20  Morris Park Bake Shop      30075445
# 21  Morris Park Bake Shop      30075445
# 22  Morris Park Bake Shop      30075445

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Idem précédemment, en se restreignant à celle ayant eu *B*

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$unwind": "$grades" },
        { "$match": { "grades.grade": "B" }}
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f4292d
# 1  5eb3d668b31de5d588f4292e
# 2  5eb3d668b31de5d588f4292f
#
#                                              address   borough        cuisine  \
# 0  {'building': '469', 'coord': [-73.961704, 40.6...  Brooklyn     Hamburgers
# 1  {'building': '1007', 'coord': [-73.856077, 40....     Bronx         Bakery
# 2  {'building': '97-22', 'coord': [-73.8601152, 4...    Queens  Jewish/Kosher
#
#                                               grades                   name  \
# 0  {'date': 2014-07-01 00:00:00, 'grade': 'B', 's...                Wendy'S
# 1  {'date': 2011-03-10 00:00:00, 'grade': 'B', 's...  Morris Park Bake Shop
# 2  {'date': 2011-12-15 00:00:00, 'grade': 'B', 's...     Tov Kosher Kitchen
#
#   restaurant_id
# 0      30112340
# 1      30075445
# 2      40356068

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Si on inverse les opérations `$unwind` et `$match`, le résultat est clairement différent

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$match": { "grades.grade": "B" }},
        { "$unwind": "$grades" }
    ]
)
pandas.DataFrame(c)
# Out:
#                          _id  \
# 0   5eb3d668b31de5d588f4292d
# 1   5eb3d668b31de5d588f4292d
# 2   5eb3d668b31de5d588f4292d
# 3   5eb3d668b31de5d588f4292d
# 4   5eb3d668b31de5d588f4292e
# 5   5eb3d668b31de5d588f4292e
# 6   5eb3d668b31de5d588f4292e
# 7   5eb3d668b31de5d588f4292e
# 8   5eb3d668b31de5d588f4292e
# 9   5eb3d668b31de5d588f4292f
# 10  5eb3d668b31de5d588f4292f
# 11  5eb3d668b31de5d588f4292f
# 12  5eb3d668b31de5d588f4292f
#
#                                               address   borough  \
# 0   {'building': '469', 'coord': [-73.961704, 40.6...  Brooklyn
# 1   {'building': '469', 'coord': [-73.961704, 40.6...  Brooklyn
# 2   {'building': '469', 'coord': [-73.961704, 40.6...  Brooklyn
# 3   {'building': '469', 'coord': [-73.961704, 40.6...  Brooklyn
# 4   {'building': '1007', 'coord': [-73.856077, 40....     Bronx
# 5   {'building': '1007', 'coord': [-73.856077, 40....     Bronx
# 6   {'building': '1007', 'coord': [-73.856077, 40....     Bronx
# 7   {'building': '1007', 'coord': [-73.856077, 40....     Bronx
# 8   {'building': '1007', 'coord': [-73.856077, 40....     Bronx
# 9   {'building': '97-22', 'coord': [-73.8601152, 4...    Queens
# 10  {'building': '97-22', 'coord': [-73.8601152, 4...    Queens
# 11  {'building': '97-22', 'coord': [-73.8601152, 4...    Queens
# 12  {'building': '97-22', 'coord': [-73.8601152, 4...    Queens
#
#           cuisine                                             grades  \
# 0      Hamburgers  {'date': 2014-12-30 00:00:00, 'grade': 'A', 's...
# 1      Hamburgers  {'date': 2014-07-01 00:00:00, 'grade': 'B', 's...
# 2      Hamburgers  {'date': 2013-04-30 00:00:00, 'grade': 'A', 's...
# 3      Hamburgers  {'date': 2012-05-08 00:00:00, 'grade': 'A', 's...
# 4          Bakery  {'date': 2014-03-03 00:00:00, 'grade': 'A', 's...
# 5          Bakery  {'date': 2013-09-11 00:00:00, 'grade': 'A', 's...
# 6          Bakery  {'date': 2013-01-24 00:00:00, 'grade': 'A', 's...
# 7          Bakery  {'date': 2011-11-23 00:00:00, 'grade': 'A', 's...
# 8          Bakery  {'date': 2011-03-10 00:00:00, 'grade': 'B', 's...
# 9   Jewish/Kosher  {'date': 2014-11-24 00:00:00, 'grade': 'Z', 's...
# 10  Jewish/Kosher  {'date': 2013-01-17 00:00:00, 'grade': 'A', 's...
# 11  Jewish/Kosher  {'date': 2012-08-02 00:00:00, 'grade': 'A', 's...
# 12  Jewish/Kosher  {'date': 2011-12-15 00:00:00, 'grade': 'B', 's...
#
#                      name restaurant_id
# 0                 Wendy'S      30112340
# 1                 Wendy'S      30112340
# 2                 Wendy'S      30112340
# 3                 Wendy'S      30112340
# 4   Morris Park Bake Shop      30075445
# 5   Morris Park Bake Shop      30075445
# 6   Morris Park Bake Shop      30075445
# 7   Morris Park Bake Shop      30075445
# 8   Morris Park Bake Shop      30075445
# 9      Tov Kosher Kitchen      40356068
# 10     Tov Kosher Kitchen      40356068
# 11     Tov Kosher Kitchen      40356068
# 12     Tov Kosher Kitchen      40356068

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On souhaite ici ne garder que le nom et le quartier des 10 premiers restaurants
#     - Notez l'ordre (alphabétique) des variables, et pas celui de la déclaration

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$project": { "name": 1, "borough": 1 } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id        borough                         name
# 0  5eb3d668b31de5d588f4292a       Brooklyn              Riviera Caterer
# 1  5eb3d668b31de5d588f4292b       Brooklyn           Wilken'S Fine Food
# 2  5eb3d668b31de5d588f4292c  Staten Island                Kosher Island
# 3  5eb3d668b31de5d588f4292d       Brooklyn                      Wendy'S
# 4  5eb3d668b31de5d588f4292e          Bronx        Morris Park Bake Shop
# 5  5eb3d668b31de5d588f4292f         Queens           Tov Kosher Kitchen
# 6  5eb3d668b31de5d588f42930         Queens      Brunos On The Boulevard
# 7  5eb3d668b31de5d588f42931       Brooklyn              Regina Caterers
# 8  5eb3d668b31de5d588f42932       Brooklyn  Taste The Tropics Ice Cream
# 9  5eb3d668b31de5d588f42933          Bronx                    Wild Asia

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Ici, on supprime l'adresse et les évaluations

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$project": { "address": 0, "grades": 0 } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id        borough                          cuisine  \
# 0  5eb3d668b31de5d588f4292a       Brooklyn                         American
# 1  5eb3d668b31de5d588f4292b       Brooklyn                     Delicatessen
# 2  5eb3d668b31de5d588f4292c  Staten Island                    Jewish/Kosher
# 3  5eb3d668b31de5d588f4292d       Brooklyn                       Hamburgers
# 4  5eb3d668b31de5d588f4292e          Bronx                           Bakery
# 5  5eb3d668b31de5d588f4292f         Queens                    Jewish/Kosher
# 6  5eb3d668b31de5d588f42930         Queens                         American
# 7  5eb3d668b31de5d588f42931       Brooklyn                         American
# 8  5eb3d668b31de5d588f42932       Brooklyn  Ice Cream, Gelato, Yogurt, Ices
# 9  5eb3d668b31de5d588f42933          Bronx                         American
#
#                           name restaurant_id
# 0              Riviera Caterer      40356018
# 1           Wilken'S Fine Food      40356483
# 2                Kosher Island      40356442
# 3                      Wendy'S      30112340
# 4        Morris Park Bake Shop      30075445
# 5           Tov Kosher Kitchen      40356068
# 6      Brunos On The Boulevard      40356151
# 7              Regina Caterers      40356649
# 8  Taste The Tropics Ice Cream      40356731
# 9                    Wild Asia      40357217

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - En plus du nom et du quartier, on récupère l'adresse mais dans un nouveau champs

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$project": { "name": 1, "borough": 1 , "street": "$address.street"} }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id        borough                         name  \
# 0  5eb3d668b31de5d588f4292a       Brooklyn              Riviera Caterer
# 1  5eb3d668b31de5d588f4292b       Brooklyn           Wilken'S Fine Food
# 2  5eb3d668b31de5d588f4292c  Staten Island                Kosher Island
# 3  5eb3d668b31de5d588f4292d       Brooklyn                      Wendy'S
# 4  5eb3d668b31de5d588f4292e          Bronx        Morris Park Bake Shop
# 5  5eb3d668b31de5d588f4292f         Queens           Tov Kosher Kitchen
# 6  5eb3d668b31de5d588f42930         Queens      Brunos On The Boulevard
# 7  5eb3d668b31de5d588f42931       Brooklyn              Regina Caterers
# 8  5eb3d668b31de5d588f42932       Brooklyn  Taste The Tropics Ice Cream
# 9  5eb3d668b31de5d588f42933          Bronx                    Wild Asia
#
#                street
# 0    Stillwell Avenue
# 1            Avenue U
# 2   Victory Boulevard
# 3     Flatbush Avenue
# 4     Morris Park Ave
# 5             63 Road
# 6   Astoria Boulevard
# 7           11 Avenue
# 8     Nostrand Avenue
# 9  Southern Boulevard

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On ajoute le nombre de visites pour chaque restaurant (donc la taille du tableau `grades`)

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$project": { "name": 1, "borough": 1, "nb_grades": { "$size": "$grades" } } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id        borough                         name  \
# 0  5eb3d668b31de5d588f4292a       Brooklyn              Riviera Caterer
# 1  5eb3d668b31de5d588f4292b       Brooklyn           Wilken'S Fine Food
# 2  5eb3d668b31de5d588f4292c  Staten Island                Kosher Island
# 3  5eb3d668b31de5d588f4292d       Brooklyn                      Wendy'S
# 4  5eb3d668b31de5d588f4292e          Bronx        Morris Park Bake Shop
# 5  5eb3d668b31de5d588f4292f         Queens           Tov Kosher Kitchen
# 6  5eb3d668b31de5d588f42930         Queens      Brunos On The Boulevard
# 7  5eb3d668b31de5d588f42931       Brooklyn              Regina Caterers
# 8  5eb3d668b31de5d588f42932       Brooklyn  Taste The Tropics Ice Cream
# 9  5eb3d668b31de5d588f42933          Bronx                    Wild Asia
#
#    nb_grades
# 0          4
# 1          6
# 2          4
# 3          4
# 4          5
# 5          4
# 6          4
# 7          5
# 8          4
# 9          3

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On trie ce résultat par nombre décroissant de visites, et on affiche les 10 premiers

# %%
c = db.restaurants.aggregate(
    [
        { "$project": { "name": 1, "borough": 1, "nb_grades": { "$size": "$grades" } } },
        { "$sort": { "nb_grades": -1 }},
        { "$limit": 10 }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id    borough                                 name  \
# 0  5eb3d668b31de5d588f4488d  Manhattan                            Nomado 33
# 1  5eb3d668b31de5d588f44658   Brooklyn                      Lai Lai Gourmet
# 2  5eb3d669b31de5d588f45fab  Manhattan                            Pure Food
# 3  5eb3d669b31de5d588f45195   Brooklyn  Silver Krust West Indian Restaurant
# 4  5eb3d668b31de5d588f441ef  Manhattan                               Benton
# 5  5eb3d669b31de5d588f45859  Manhattan           Breeze Thai-French Kitchen
# 6  5eb3d668b31de5d588f44361   Brooklyn                       Noodle Station
# 7  5eb3d668b31de5d588f441c2  Manhattan                                S'Mac
# 8  5eb3d668b31de5d588f42c95      Bronx            El Molino Rojo Restaurant
# 9  5eb3d668b31de5d588f42d78  Manhattan                       World Cup Cafe
#
#    nb_grades
# 0          9
# 1          9
# 2          9
# 3          9
# 4          9
# 5          9
# 6          9
# 7          9
# 8          8
# 9          8

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On ne garde maintenant que le premier élément du tableau `grades` (indicé 0)

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$project": { "name": 1, "borough": 1, "grade": { "$arrayElemAt": [ "$grades", 0 ]} } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id        borough                         name  \
# 0  5eb3d668b31de5d588f4292a       Brooklyn              Riviera Caterer
# 1  5eb3d668b31de5d588f4292b       Brooklyn           Wilken'S Fine Food
# 2  5eb3d668b31de5d588f4292c  Staten Island                Kosher Island
# 3  5eb3d668b31de5d588f4292d       Brooklyn                      Wendy'S
# 4  5eb3d668b31de5d588f4292e          Bronx        Morris Park Bake Shop
# 5  5eb3d668b31de5d588f4292f         Queens           Tov Kosher Kitchen
# 6  5eb3d668b31de5d588f42930         Queens      Brunos On The Boulevard
# 7  5eb3d668b31de5d588f42931       Brooklyn              Regina Caterers
# 8  5eb3d668b31de5d588f42932       Brooklyn  Taste The Tropics Ice Cream
# 9  5eb3d668b31de5d588f42933          Bronx                    Wild Asia
#
#                                                grade
# 0  {'date': 2014-06-10 00:00:00, 'grade': 'A', 's...
# 1  {'date': 2014-05-29 00:00:00, 'grade': 'A', 's...
# 2  {'date': 2014-10-06 00:00:00, 'grade': 'A', 's...
# 3  {'date': 2014-12-30 00:00:00, 'grade': 'A', 's...
# 4  {'date': 2014-03-03 00:00:00, 'grade': 'A', 's...
# 5  {'date': 2014-11-24 00:00:00, 'grade': 'Z', 's...
# 6  {'date': 2014-11-15 00:00:00, 'grade': 'Z', 's...
# 7  {'date': 2014-07-18 00:00:00, 'grade': 'A', 's...
# 8  {'date': 2014-07-14 00:00:00, 'grade': 'A', 's...
# 9  {'date': 2014-05-28 00:00:00, 'grade': 'A', 's...

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - `$first` permet aussi de garder uniquement le premier élément du tableau `grades` de façon explicite (`$last` pour le dernier)

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$project": { "name": 1, "borough": 1, "grade": { "$first": "$grades" } } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id        borough                         name  \
# 0  5eb3d668b31de5d588f4292a       Brooklyn              Riviera Caterer
# 1  5eb3d668b31de5d588f4292b       Brooklyn           Wilken'S Fine Food
# 2  5eb3d668b31de5d588f4292c  Staten Island                Kosher Island
# 3  5eb3d668b31de5d588f4292d       Brooklyn                      Wendy'S
# 4  5eb3d668b31de5d588f4292e          Bronx        Morris Park Bake Shop
# 5  5eb3d668b31de5d588f4292f         Queens           Tov Kosher Kitchen
# 6  5eb3d668b31de5d588f42930         Queens      Brunos On The Boulevard
# 7  5eb3d668b31de5d588f42931       Brooklyn              Regina Caterers
# 8  5eb3d668b31de5d588f42932       Brooklyn  Taste The Tropics Ice Cream
# 9  5eb3d668b31de5d588f42933          Bronx                    Wild Asia
#
#                                                grade
# 0  {'date': 2014-06-10 00:00:00, 'grade': 'A', 's...
# 1  {'date': 2014-05-29 00:00:00, 'grade': 'A', 's...
# 2  {'date': 2014-10-06 00:00:00, 'grade': 'A', 's...
# 3  {'date': 2014-12-30 00:00:00, 'grade': 'A', 's...
# 4  {'date': 2014-03-03 00:00:00, 'grade': 'A', 's...
# 5  {'date': 2014-11-24 00:00:00, 'grade': 'Z', 's...
# 6  {'date': 2014-11-15 00:00:00, 'grade': 'Z', 's...
# 7  {'date': 2014-07-18 00:00:00, 'grade': 'A', 's...
# 8  {'date': 2014-07-14 00:00:00, 'grade': 'A', 's...
# 9  {'date': 2014-05-28 00:00:00, 'grade': 'A', 's...

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On peut aussi faire des opérations sur les chaînes, tel que la mise en majuscule du nom

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$project": { "nom": { "$toUpper": "$name" }, "borough": 1 } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id        borough                          nom
# 0  5eb3d668b31de5d588f4292a       Brooklyn              RIVIERA CATERER
# 1  5eb3d668b31de5d588f4292b       Brooklyn           WILKEN'S FINE FOOD
# 2  5eb3d668b31de5d588f4292c  Staten Island                KOSHER ISLAND
# 3  5eb3d668b31de5d588f4292d       Brooklyn                      WENDY'S
# 4  5eb3d668b31de5d588f4292e          Bronx        MORRIS PARK BAKE SHOP
# 5  5eb3d668b31de5d588f4292f         Queens           TOV KOSHER KITCHEN
# 6  5eb3d668b31de5d588f42930         Queens      BRUNOS ON THE BOULEVARD
# 7  5eb3d668b31de5d588f42931       Brooklyn              REGINA CATERERS
# 8  5eb3d668b31de5d588f42932       Brooklyn  TASTE THE TROPICS ICE CREAM
# 9  5eb3d668b31de5d588f42933          Bronx                    WILD ASIA

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On peut aussi vouloir ajouter un champs, comme ici le nombre d'évaluations

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$addFields": { "nb_grades": { "$size": "$grades" } } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f4292a
# 1  5eb3d668b31de5d588f4292b
# 2  5eb3d668b31de5d588f4292c
# 3  5eb3d668b31de5d588f4292d
# 4  5eb3d668b31de5d588f4292e
# 5  5eb3d668b31de5d588f4292f
# 6  5eb3d668b31de5d588f42930
# 7  5eb3d668b31de5d588f42931
# 8  5eb3d668b31de5d588f42932
# 9  5eb3d668b31de5d588f42933
#
#                                              address        borough  \
# 0  {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1  {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 2  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 3  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 4  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 5  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 6  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 7  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 8  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 9  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
#
#                            cuisine  \
# 0                         American
# 1                     Delicatessen
# 2                    Jewish/Kosher
# 3                       Hamburgers
# 4                           Bakery
# 5                    Jewish/Kosher
# 6                         American
# 7                         American
# 8  Ice Cream, Gelato, Yogurt, Ices
# 9                         American
#
#                                               grades  \
# 0  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 1  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
# 2  [{'date': 2014-10-06 00:00:00, 'grade': 'A', '...
# 3  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 4  [{'date': 2014-03-03 00:00:00, 'grade': 'A', '...
# 5  [{'date': 2014-11-24 00:00:00, 'grade': 'Z', '...
# 6  [{'date': 2014-11-15 00:00:00, 'grade': 'Z', '...
# 7  [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 8  [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 9  [{'date': 2014-05-28 00:00:00, 'grade': 'A', '...
#
#                           name restaurant_id  nb_grades
# 0              Riviera Caterer      40356018          4
# 1           Wilken'S Fine Food      40356483          6
# 2                Kosher Island      40356442          4
# 3                      Wendy'S      30112340          4
# 4        Morris Park Bake Shop      30075445          5
# 5           Tov Kosher Kitchen      40356068          4
# 6      Brunos On The Boulevard      40356151          4
# 7              Regina Caterers      40356649          5
# 8  Taste The Tropics Ice Cream      40356731          4
# 9                    Wild Asia      40357217          3

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On extrait ici les trois premières lettres du quartier

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$project": { 
            "nom": { "$toUpper": "$name" }, 
            "quartier": { "$substr": [ "$borough", 0, 3 ] } 
        } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id                          nom quartier
# 0  5eb3d668b31de5d588f4292a              RIVIERA CATERER      Bro
# 1  5eb3d668b31de5d588f4292b           WILKEN'S FINE FOOD      Bro
# 2  5eb3d668b31de5d588f4292c                KOSHER ISLAND      Sta
# 3  5eb3d668b31de5d588f4292d                      WENDY'S      Bro
# 4  5eb3d668b31de5d588f4292e        MORRIS PARK BAKE SHOP      Bro
# 5  5eb3d668b31de5d588f4292f           TOV KOSHER KITCHEN      Que
# 6  5eb3d668b31de5d588f42930      BRUNOS ON THE BOULEVARD      Que
# 7  5eb3d668b31de5d588f42931              REGINA CATERERS      Bro
# 8  5eb3d668b31de5d588f42932  TASTE THE TROPICS ICE CREAM      Bro
# 9  5eb3d668b31de5d588f42933                    WILD ASIA      Bro

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On fait de même, mais on met en majuscule et on note *BRX* pour le *Bronx*
#     - on garde le quartier d'origine pour vérification ici

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$addFields": { "quartier": { "$toUpper": { "$substr": [ "$borough", 0, 3 ] } } }},
        { "$project": { 
            "nom": { "$toUpper": "$name" }, 
            "quartier": { "$cond": { 
                "if": { "$eq": ["$borough", "Bronx"] }, 
                "then": "BRX", 
                "else": "$quartier" 
            } },
            "borough": 1
        } }
    ]
)
pandas.DataFrame(c)
# Out:
#                         _id        borough                          nom  \
# 0  5eb3d668b31de5d588f4292a       Brooklyn              RIVIERA CATERER
# 1  5eb3d668b31de5d588f4292b       Brooklyn           WILKEN'S FINE FOOD
# 2  5eb3d668b31de5d588f4292c  Staten Island                KOSHER ISLAND
# 3  5eb3d668b31de5d588f4292d       Brooklyn                      WENDY'S
# 4  5eb3d668b31de5d588f4292e          Bronx        MORRIS PARK BAKE SHOP
# 5  5eb3d668b31de5d588f4292f         Queens           TOV KOSHER KITCHEN
# 6  5eb3d668b31de5d588f42930         Queens      BRUNOS ON THE BOULEVARD
# 7  5eb3d668b31de5d588f42931       Brooklyn              REGINA CATERERS
# 8  5eb3d668b31de5d588f42932       Brooklyn  TASTE THE TROPICS ICE CREAM
# 9  5eb3d668b31de5d588f42933          Bronx                    WILD ASIA
#
#   quartier
# 0      BRO
# 1      BRO
# 2      STA
# 3      BRO
# 4      BRX
# 5      QUE
# 6      QUE
# 7      BRO
# 8      BRO
# 9      BRX

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On calcule ici le nombre total de restaurants

# %%
c = db.restaurants.aggregate(
    [
        {"$group": {"_id": "Total", "NbRestos": {"$sum": 1}}}
    ]
)
pandas.DataFrame(c)
# Out:
#      _id  NbRestos
# 0  Total     25359

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On fait de même, mais par quartier

# %%
c = db.restaurants.aggregate(
    [
        {"$group": {"_id": "$borough", "NbRestos": {"$sum": 1}}}
    ]
)
pandas.DataFrame(c)
# Out:
#              _id  NbRestos
# 0  Staten Island       969
# 1       Brooklyn      6086
# 2          Bronx      2338
# 3         Queens      5656
# 4      Manhattan     10259
# 5        Missing        51

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Une fois le dénombrement fait, on peut aussi trié le résultat

# %%
c = db.restaurants.aggregate(
    [
        {"$group": {"_id": "$borough", "NbRestos": {"$sum": 1}}},
        {"$sort": { "NbRestos": -1}}
    ]
)
pandas.DataFrame(c)
# Out:
#              _id  NbRestos
# 0      Manhattan     10259
# 1       Brooklyn      6086
# 2         Queens      5656
# 3          Bronx      2338
# 4  Staten Island       969
# 5        Missing        51

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - La même opération est réalisable directement avec `$sortByCount`

# %%
c = db.restaurants.aggregate(
    [
        {"$sortByCount": "$borough"}
    ]
)
pandas.DataFrame(c)
# Out:
#              _id  count
# 0      Manhattan  10259
# 1       Brooklyn   6086
# 2         Queens   5656
# 3          Bronx   2338
# 4  Staten Island    969
# 5        Missing     51

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Pour faire le calcul des notes moyennes des restaurants du *Queens*, on exécute le code suivant

# %%
c = db.restaurants.aggregate(
    [
        { "$match": { "borough": "Queens" }},
        { "$unwind": "$grades" },
        { "$group": { "_id": "null", "score": { "$avg": "$grades.score" }}}
    ]
)
pandas.DataFrame(c)
# Out:
#     _id      score
# 0  null  11.634865

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# -  Il est bien évidemment possible de faire ce calcul par quartier et de les trier selon les notes obtenues (dans l'ordre décroissant)

# %%
c = db.restaurants.aggregate(
    [
        { "$unwind": "$grades" },
        { "$group": { "_id": "$borough", "score": { "$avg": "$grades.score" }}},
        { "$sort": { "score": -1 }}
    ]
)
pandas.DataFrame(c)
# Out:
#              _id      score
# 0         Queens  11.634865
# 1       Brooklyn  11.447976
# 2      Manhattan  11.418151
# 3  Staten Island  11.370958
# 4          Bronx  11.036186
# 5        Missing   9.632911

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - On peut aussi faire un regroupement par quartier et par rue (en ne prenant que la première évaluation - qui est la dernière en date a priori), pour afficher les 10 rues où on mange le plus sainement
#     - Notez que le `$match` permet de supprimer les restaurants sans évaluations (ce qui engendrerait des moyennes = `None`)

# %%
c = db.restaurants.aggregate(
    [
        { "$project": {
            "borough": 1, "street": "$address.street", 
            "eval": { "$arrayElemAt": [ "$grades", 0 ]} 
        } },
        { "$match": { "eval": { "$exists": True } } },
        { "$group": { 
            "_id": { "quartier": "$borough", "rue": "$street" }, 
            "score": { "$avg": "$eval.score" }
        }},
        { "$sort": { "score": 1 }},
        { "$limit": 10 }
    ]
)
pandas.DataFrame(c)
# Out:
#                                                  _id  score
# 0  {'quartier': 'Manhattan', 'rue': '106 Street &...   -1.0
# 1          {'quartier': 'Queens', 'rue': '100Th St'}    0.0
# 2         {'quartier': 'Manhattan', 'rue': 'E Bway'}    0.0
# 3      {'quartier': 'Brooklyn', 'rue': 'Gateway Dr'}    0.0
# 4    {'quartier': 'Bronx', 'rue': 'East 208 Street'}    0.0
# 5         {'quartier': 'Bronx', 'rue': 'E 174Th St'}    0.0
# 6   {'quartier': 'Manhattan', 'rue': 'Leroy Street'}    0.0
# 7  {'quartier': 'Staten Island', 'rue': 'Eton Pla...    0.0
# 8  {'quartier': 'Manhattan', 'rue': 'River Terrace'}    0.0
# 9    {'quartier': 'Brooklyn', 'rue': 'Stockholm St'}    0.0

# %% [markdown]
# #### Calcul d'agrégat (suite)
#
#
# - Pour comprendre la différence entre `$addToSet` et `$push`, on les applique sur les grades obtenus pour les 10 premiers restaurants
#     - `$addToSet` : valeurs distinctes
#     - `$push` : toutes les valeurs présentes

# %%
c = db.restaurants.aggregate(
    [
        { "$limit": 10 },
        { "$unwind": "$grades" },
        { "$group": { 
            "_id": "$name", 
            "avec_addToSet": { "$addToSet": "$grades.grade" },
            "avec_push": { "$push": "$grades.grade" }
        }}
    ]
)
pandas.DataFrame(c)
# Out:
#                            _id avec_addToSet           avec_push
# 0      Brunos On The Boulevard        [A, Z]        [Z, A, A, A]
# 1              Regina Caterers           [A]     [A, A, A, A, A]
# 2                    Wild Asia           [A]           [A, A, A]
# 3  Taste The Tropics Ice Cream           [A]        [A, A, A, A]
# 4              Riviera Caterer           [A]        [A, A, A, A]
# 5           Wilken'S Fine Food           [A]  [A, A, A, A, A, A]
# 6           Tov Kosher Kitchen     [B, A, Z]        [Z, A, A, B]
# 7                Kosher Island           [A]        [A, A, A, A]
# 8                      Wendy'S        [A, B]        [A, B, A, A]
# 9        Morris Park Bake Shop        [B, A]     [A, A, A, A, B]

# %% [markdown]
# ### Itération
#
# Il est possible de définir un curseur qui va itérer sur la liste de résultats (celle-ci sera stocké sur le serveur). Cela permet de récupérer les documents par paquets, ce qui est judicieux en cas de gros volume (pour éviter de congestionner un réseau par exemple).

# %%
cursor = db.restaurants.find(
    {"borough": "Queens", "grades.score": { "$gte":  50}},
    {"_id": 0, "name": 1, "address.street": 1},
    batch_size = 10)

# %% [markdown]
# Mais l'opération est totalement transparente dans python, puisque lorsque nous appelons le curseur, nous récupérons tous les documents.

# %%
pandas.DataFrame(cursor)
# Out:
#                                    address                        name
# 0   {'street': 'Horace Harding Boulevard'}             Richer'S Bakery
# 1             {'street': 'Bell Boulevard'}            Tequilla Sunrise
# 2   {'street': 'Rockaway Beach Boulevard'}          Rockaway Beach Inn
# 3                   {'street': 'Broadway'}               Alfonso'S Bar
# 4        {'street': 'Woodhaven Boulevard'}                     Pio Pio
# ..                                     ...                         ...
# 78                 {'street': '30 Avenue'}   Queens Comfort Restaurant
# 79            {'street': 'Union Turnpike'}                       Koyla
# 80                   {'street': '37 Road'}  Jackson Heights Food Court
# 81              {'street': 'Union Street'}          K & D Internet Inc
# 82             {'street': 'Roosevelt Ave'}            Tacos Al Suadero
#
# [83 rows x 2 columns]

# %% [markdown]
# ## Gestion des variables spéciales dans le DataFrame
#
# Une fois importées dans un `DataFrame`, les champs complexes (comme `address` et `grades`) sont des variables d'un type un peu particulier.

# %%
df = pandas.DataFrame(db.restaurants.find(limit = 10))
df
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f4292a
# 1  5eb3d668b31de5d588f4292b
# 2  5eb3d668b31de5d588f4292c
# 3  5eb3d668b31de5d588f4292d
# 4  5eb3d668b31de5d588f4292e
# 5  5eb3d668b31de5d588f4292f
# 6  5eb3d668b31de5d588f42930
# 7  5eb3d668b31de5d588f42931
# 8  5eb3d668b31de5d588f42932
# 9  5eb3d668b31de5d588f42933
#
#                                              address        borough  \
# 0  {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1  {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 2  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 3  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 4  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 5  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 6  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 7  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 8  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 9  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
#
#                            cuisine  \
# 0                         American
# 1                     Delicatessen
# 2                    Jewish/Kosher
# 3                       Hamburgers
# 4                           Bakery
# 5                    Jewish/Kosher
# 6                         American
# 7                         American
# 8  Ice Cream, Gelato, Yogurt, Ices
# 9                         American
#
#                                               grades  \
# 0  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 1  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
# 2  [{'date': 2014-10-06 00:00:00, 'grade': 'A', '...
# 3  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 4  [{'date': 2014-03-03 00:00:00, 'grade': 'A', '...
# 5  [{'date': 2014-11-24 00:00:00, 'grade': 'Z', '...
# 6  [{'date': 2014-11-15 00:00:00, 'grade': 'Z', '...
# 7  [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 8  [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 9  [{'date': 2014-05-28 00:00:00, 'grade': 'A', '...
#
#                           name restaurant_id
# 0              Riviera Caterer      40356018
# 1           Wilken'S Fine Food      40356483
# 2                Kosher Island      40356442
# 3                      Wendy'S      30112340
# 4        Morris Park Bake Shop      30075445
# 5           Tov Kosher Kitchen      40356068
# 6      Brunos On The Boulevard      40356151
# 7              Regina Caterers      40356649
# 8  Taste The Tropics Ice Cream      40356731
# 9                    Wild Asia      40357217

# %% [markdown]
# ### Variables ayant des dictionnaires comme valeurs
#
# Le champs `address` est une liste de dictionnaires, ayant chacun plusieurs champs (ici tous les mêmes).

# %%
df.address
# Out:
# 0    {'building': '2780', 'coord': [-73.98241999999...
# 1    {'building': '7114', 'coord': [-73.9068506, 40...
# 2    {'building': '2206', 'coord': [-74.1377286, 40...
# 3    {'building': '469', 'coord': [-73.961704, 40.6...
# 4    {'building': '1007', 'coord': [-73.856077, 40....
# 5    {'building': '97-22', 'coord': [-73.8601152, 4...
# 6    {'building': '8825', 'coord': [-73.8803827, 40...
# 7    {'building': '6409', 'coord': [-74.00528899999...
# 8    {'building': '1839', 'coord': [-73.9482609, 40...
# 9    {'building': '2300', 'coord': [-73.8786113, 40...
# Name: address, dtype: object

# %% [markdown]
# #### Manipulation simple
#
# - Nom du bâtiment et rue concaténés dans une nouvelle variable de `df`
#     - utilisation de *list comprehension*

# %%
df.assign(info = [e["building"] + ", " + e["street"] for e in df.address])
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f4292a
# 1  5eb3d668b31de5d588f4292b
# 2  5eb3d668b31de5d588f4292c
# 3  5eb3d668b31de5d588f4292d
# 4  5eb3d668b31de5d588f4292e
# 5  5eb3d668b31de5d588f4292f
# 6  5eb3d668b31de5d588f42930
# 7  5eb3d668b31de5d588f42931
# 8  5eb3d668b31de5d588f42932
# 9  5eb3d668b31de5d588f42933
#
#                                              address        borough  \
# 0  {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1  {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 2  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 3  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 4  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 5  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 6  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 7  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 8  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 9  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
#
#                            cuisine  \
# 0                         American
# 1                     Delicatessen
# 2                    Jewish/Kosher
# 3                       Hamburgers
# 4                           Bakery
# 5                    Jewish/Kosher
# 6                         American
# 7                         American
# 8  Ice Cream, Gelato, Yogurt, Ices
# 9                         American
#
#                                               grades  \
# 0  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 1  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
# 2  [{'date': 2014-10-06 00:00:00, 'grade': 'A', '...
# 3  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 4  [{'date': 2014-03-03 00:00:00, 'grade': 'A', '...
# 5  [{'date': 2014-11-24 00:00:00, 'grade': 'Z', '...
# 6  [{'date': 2014-11-15 00:00:00, 'grade': 'Z', '...
# 7  [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 8  [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 9  [{'date': 2014-05-28 00:00:00, 'grade': 'A', '...
#
#                           name restaurant_id                      info
# 0              Riviera Caterer      40356018    2780, Stillwell Avenue
# 1           Wilken'S Fine Food      40356483            7114, Avenue U
# 2                Kosher Island      40356442   2206, Victory Boulevard
# 3                      Wendy'S      30112340      469, Flatbush Avenue
# 4        Morris Park Bake Shop      30075445     1007, Morris Park Ave
# 5           Tov Kosher Kitchen      40356068            97-22, 63 Road
# 6      Brunos On The Boulevard      40356151   8825, Astoria Boulevard
# 7              Regina Caterers      40356649           6409, 11 Avenue
# 8  Taste The Tropics Ice Cream      40356731     1839, Nostrand Avenue
# 9                    Wild Asia      40357217  2300, Southern Boulevard

# %% [markdown]
# #### Manipulation plus complexe
#
# - Transformation de la liste en un `DataFrame`

# %%
pandas.DataFrame([e for e in df.address])
# Out:
#   building                            coord              street zipcode
# 0     2780  [-73.98241999999999, 40.579505]    Stillwell Avenue   11224
# 1     7114        [-73.9068506, 40.6199034]            Avenue U   11234
# 2     2206        [-74.1377286, 40.6119572]   Victory Boulevard   10314
# 3      469          [-73.961704, 40.662942]     Flatbush Avenue   11225
# 4     1007          [-73.856077, 40.848447]     Morris Park Ave   10462
# 5    97-22        [-73.8601152, 40.7311739]             63 Road   11374
# 6     8825        [-73.8803827, 40.7643124]   Astoria Boulevard   11369
# 7     6409  [-74.00528899999999, 40.628886]           11 Avenue   11219
# 8     1839        [-73.9482609, 40.6408271]     Nostrand Avenue   11226
# 9     2300        [-73.8786113, 40.8502883]  Southern Boulevard   10460

# %% [markdown]
# #### Idem en intégrant le résultat dans le `DataFrame`  original

# %%
pandas.concat([df.drop("address", axis = 1), pandas.DataFrame([e for e in df.address])], axis = 1)
# Out:
#                         _id        borough                          cuisine  \
# 0  5eb3d668b31de5d588f4292a       Brooklyn                         American
# 1  5eb3d668b31de5d588f4292b       Brooklyn                     Delicatessen
# 2  5eb3d668b31de5d588f4292c  Staten Island                    Jewish/Kosher
# 3  5eb3d668b31de5d588f4292d       Brooklyn                       Hamburgers
# 4  5eb3d668b31de5d588f4292e          Bronx                           Bakery
# 5  5eb3d668b31de5d588f4292f         Queens                    Jewish/Kosher
# 6  5eb3d668b31de5d588f42930         Queens                         American
# 7  5eb3d668b31de5d588f42931       Brooklyn                         American
# 8  5eb3d668b31de5d588f42932       Brooklyn  Ice Cream, Gelato, Yogurt, Ices
# 9  5eb3d668b31de5d588f42933          Bronx                         American
#
#                                               grades  \
# 0  [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 1  [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
# 2  [{'date': 2014-10-06 00:00:00, 'grade': 'A', '...
# 3  [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 4  [{'date': 2014-03-03 00:00:00, 'grade': 'A', '...
# 5  [{'date': 2014-11-24 00:00:00, 'grade': 'Z', '...
# 6  [{'date': 2014-11-15 00:00:00, 'grade': 'Z', '...
# 7  [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 8  [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 9  [{'date': 2014-05-28 00:00:00, 'grade': 'A', '...
#
#                           name restaurant_id building  \
# 0              Riviera Caterer      40356018     2780
# 1           Wilken'S Fine Food      40356483     7114
# 2                Kosher Island      40356442     2206
# 3                      Wendy'S      30112340      469
# 4        Morris Park Bake Shop      30075445     1007
# 5           Tov Kosher Kitchen      40356068    97-22
# 6      Brunos On The Boulevard      40356151     8825
# 7              Regina Caterers      40356649     6409
# 8  Taste The Tropics Ice Cream      40356731     1839
# 9                    Wild Asia      40357217     2300
#
#                              coord              street zipcode
# 0  [-73.98241999999999, 40.579505]    Stillwell Avenue   11224
# 1        [-73.9068506, 40.6199034]            Avenue U   11234
# 2        [-74.1377286, 40.6119572]   Victory Boulevard   10314
# 3          [-73.961704, 40.662942]     Flatbush Avenue   11225
# 4          [-73.856077, 40.848447]     Morris Park Ave   10462
# 5        [-73.8601152, 40.7311739]             63 Road   11374
# 6        [-73.8803827, 40.7643124]   Astoria Boulevard   11369
# 7  [-74.00528899999999, 40.628886]           11 Avenue   11219
# 8        [-73.9482609, 40.6408271]     Nostrand Avenue   11226
# 9        [-73.8786113, 40.8502883]  Southern Boulevard   10460

# %% [markdown]
# ### Variables ayant des tableaux comme valeurs
#
# Le champs `grades` est une liste de tableaux, ayant chacun potentiellement plusieurs valeurs (des dictionnaires de plus)

# %%
df.grades
# Out:
# 0    [{'date': 2014-06-10 00:00:00, 'grade': 'A', '...
# 1    [{'date': 2014-05-29 00:00:00, 'grade': 'A', '...
# 2    [{'date': 2014-10-06 00:00:00, 'grade': 'A', '...
# 3    [{'date': 2014-12-30 00:00:00, 'grade': 'A', '...
# 4    [{'date': 2014-03-03 00:00:00, 'grade': 'A', '...
# 5    [{'date': 2014-11-24 00:00:00, 'grade': 'Z', '...
# 6    [{'date': 2014-11-15 00:00:00, 'grade': 'Z', '...
# 7    [{'date': 2014-07-18 00:00:00, 'grade': 'A', '...
# 8    [{'date': 2014-07-14 00:00:00, 'grade': 'A', '...
# 9    [{'date': 2014-05-28 00:00:00, 'grade': 'A', '...
# Name: grades, dtype: object

# %% [markdown]
# #### Manipulation simple
#
# - Récupération d'un élément du tableau (premier ou dernier)

# %%
df.assign(derniere = [e[0] for e in df.grades], premiere = [e[-1] for e in df.grades]).drop("grades", axis = 1)
# Out:
#                         _id  \
# 0  5eb3d668b31de5d588f4292a
# 1  5eb3d668b31de5d588f4292b
# 2  5eb3d668b31de5d588f4292c
# 3  5eb3d668b31de5d588f4292d
# 4  5eb3d668b31de5d588f4292e
# 5  5eb3d668b31de5d588f4292f
# 6  5eb3d668b31de5d588f42930
# 7  5eb3d668b31de5d588f42931
# 8  5eb3d668b31de5d588f42932
# 9  5eb3d668b31de5d588f42933
#
#                                              address        borough  \
# 0  {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1  {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 2  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 3  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 4  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 5  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 6  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 7  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 8  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 9  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
#
#                            cuisine                         name restaurant_id  \
# 0                         American              Riviera Caterer      40356018
# 1                     Delicatessen           Wilken'S Fine Food      40356483
# 2                    Jewish/Kosher                Kosher Island      40356442
# 3                       Hamburgers                      Wendy'S      30112340
# 4                           Bakery        Morris Park Bake Shop      30075445
# 5                    Jewish/Kosher           Tov Kosher Kitchen      40356068
# 6                         American      Brunos On The Boulevard      40356151
# 7                         American              Regina Caterers      40356649
# 8  Ice Cream, Gelato, Yogurt, Ices  Taste The Tropics Ice Cream      40356731
# 9                         American                    Wild Asia      40357217
#
#                                             derniere  \
# 0  {'date': 2014-06-10 00:00:00, 'grade': 'A', 's...
# 1  {'date': 2014-05-29 00:00:00, 'grade': 'A', 's...
# 2  {'date': 2014-10-06 00:00:00, 'grade': 'A', 's...
# 3  {'date': 2014-12-30 00:00:00, 'grade': 'A', 's...
# 4  {'date': 2014-03-03 00:00:00, 'grade': 'A', 's...
# 5  {'date': 2014-11-24 00:00:00, 'grade': 'Z', 's...
# 6  {'date': 2014-11-15 00:00:00, 'grade': 'Z', 's...
# 7  {'date': 2014-07-18 00:00:00, 'grade': 'A', 's...
# 8  {'date': 2014-07-14 00:00:00, 'grade': 'A', 's...
# 9  {'date': 2014-05-28 00:00:00, 'grade': 'A', 's...
#
#                                             premiere
# 0  {'date': 2011-10-12 00:00:00, 'grade': 'A', 's...
# 1  {'date': 2011-10-14 00:00:00, 'grade': 'A', 's...
# 2  {'date': 2012-01-24 00:00:00, 'grade': 'A', 's...
# 3  {'date': 2012-05-08 00:00:00, 'grade': 'A', 's...
# 4  {'date': 2011-03-10 00:00:00, 'grade': 'B', 's...
# 5  {'date': 2011-12-15 00:00:00, 'grade': 'B', 's...
# 6  {'date': 2012-02-10 00:00:00, 'grade': 'A', 's...
# 7  {'date': 2011-08-17 00:00:00, 'grade': 'A', 's...
# 8  {'date': 2012-02-23 00:00:00, 'grade': 'A', 's...
# 9  {'date': 2012-06-15 00:00:00, 'grade': 'A', 's...

# %% [markdown]
# #### Manipulation plus complexe
#
# - Transformation de la liste de tableaux en un seul `DataFrame`
#     - `zip()` permet d'itérer sur plusieurs tableaux en même temps
#     - `concat()` permet de concaténer les tableaux entre eux

# %%
dfgrades = pandas.concat([pandas.DataFrame(g).assign(_id = i) for (i, g) in zip(df._id, df.grades)])
dfgrades
# Out:
#         date grade  score                       _id
# 0 2014-06-10     A      5  5eb3d668b31de5d588f4292a
# 1 2013-06-05     A      7  5eb3d668b31de5d588f4292a
# 2 2012-04-13     A     12  5eb3d668b31de5d588f4292a
# 3 2011-10-12     A     12  5eb3d668b31de5d588f4292a
# 0 2014-05-29     A     10  5eb3d668b31de5d588f4292b
# 1 2014-01-14     A     10  5eb3d668b31de5d588f4292b
# 2 2013-08-03     A      8  5eb3d668b31de5d588f4292b
# 3 2012-07-18     A     10  5eb3d668b31de5d588f4292b
# 4 2012-03-09     A     13  5eb3d668b31de5d588f4292b
# 5 2011-10-14     A      9  5eb3d668b31de5d588f4292b
# 0 2014-10-06     A      9  5eb3d668b31de5d588f4292c
# 1 2014-05-20     A     12  5eb3d668b31de5d588f4292c
# 2 2013-04-04     A     12  5eb3d668b31de5d588f4292c
# 3 2012-01-24     A      9  5eb3d668b31de5d588f4292c
# 0 2014-12-30     A      8  5eb3d668b31de5d588f4292d
# 1 2014-07-01     B     23  5eb3d668b31de5d588f4292d
# 2 2013-04-30     A     12  5eb3d668b31de5d588f4292d
# 3 2012-05-08     A     12  5eb3d668b31de5d588f4292d
# 0 2014-03-03     A      2  5eb3d668b31de5d588f4292e
# 1 2013-09-11     A      6  5eb3d668b31de5d588f4292e
# 2 2013-01-24     A     10  5eb3d668b31de5d588f4292e
# 3 2011-11-23     A      9  5eb3d668b31de5d588f4292e
# 4 2011-03-10     B     14  5eb3d668b31de5d588f4292e
# 0 2014-11-24     Z     20  5eb3d668b31de5d588f4292f
# 1 2013-01-17     A     13  5eb3d668b31de5d588f4292f
# 2 2012-08-02     A     13  5eb3d668b31de5d588f4292f
# 3 2011-12-15     B     25  5eb3d668b31de5d588f4292f
# 0 2014-11-15     Z     38  5eb3d668b31de5d588f42930
# 1 2014-05-02     A     10  5eb3d668b31de5d588f42930
# 2 2013-03-02     A      7  5eb3d668b31de5d588f42930
# 3 2012-02-10     A     13  5eb3d668b31de5d588f42930
# 0 2014-07-18     A     12  5eb3d668b31de5d588f42931
# 1 2013-07-30     A     12  5eb3d668b31de5d588f42931
# 2 2013-02-13     A     11  5eb3d668b31de5d588f42931
# 3 2012-08-16     A      2  5eb3d668b31de5d588f42931
# 4 2011-08-17     A     11  5eb3d668b31de5d588f42931
# 0 2014-07-14     A     12  5eb3d668b31de5d588f42932
# 1 2013-07-10     A      8  5eb3d668b31de5d588f42932
# 2 2012-07-11     A      5  5eb3d668b31de5d588f42932
# 3 2012-02-23     A      8  5eb3d668b31de5d588f42932
# 0 2014-05-28     A     11  5eb3d668b31de5d588f42933
# 1 2013-06-19     A      4  5eb3d668b31de5d588f42933
# 2 2012-06-15     A      3  5eb3d668b31de5d588f42933

# %% [markdown]
# #### Combinaison avec les données originales
#
# - Jointure entre les deux `DataFrames` avec `merge()`

# %%
pandas.merge(df.drop("grades", axis = 1), dfgrades.reset_index())
# Out:
#                          _id  \
# 0   5eb3d668b31de5d588f4292a
# 1   5eb3d668b31de5d588f4292a
# 2   5eb3d668b31de5d588f4292a
# 3   5eb3d668b31de5d588f4292a
# 4   5eb3d668b31de5d588f4292b
# 5   5eb3d668b31de5d588f4292b
# 6   5eb3d668b31de5d588f4292b
# 7   5eb3d668b31de5d588f4292b
# 8   5eb3d668b31de5d588f4292b
# 9   5eb3d668b31de5d588f4292b
# 10  5eb3d668b31de5d588f4292c
# 11  5eb3d668b31de5d588f4292c
# 12  5eb3d668b31de5d588f4292c
# 13  5eb3d668b31de5d588f4292c
# 14  5eb3d668b31de5d588f4292d
# 15  5eb3d668b31de5d588f4292d
# 16  5eb3d668b31de5d588f4292d
# 17  5eb3d668b31de5d588f4292d
# 18  5eb3d668b31de5d588f4292e
# 19  5eb3d668b31de5d588f4292e
# 20  5eb3d668b31de5d588f4292e
# 21  5eb3d668b31de5d588f4292e
# 22  5eb3d668b31de5d588f4292e
# 23  5eb3d668b31de5d588f4292f
# 24  5eb3d668b31de5d588f4292f
# 25  5eb3d668b31de5d588f4292f
# 26  5eb3d668b31de5d588f4292f
# 27  5eb3d668b31de5d588f42930
# 28  5eb3d668b31de5d588f42930
# 29  5eb3d668b31de5d588f42930
# 30  5eb3d668b31de5d588f42930
# 31  5eb3d668b31de5d588f42931
# 32  5eb3d668b31de5d588f42931
# 33  5eb3d668b31de5d588f42931
# 34  5eb3d668b31de5d588f42931
# 35  5eb3d668b31de5d588f42931
# 36  5eb3d668b31de5d588f42932
# 37  5eb3d668b31de5d588f42932
# 38  5eb3d668b31de5d588f42932
# 39  5eb3d668b31de5d588f42932
# 40  5eb3d668b31de5d588f42933
# 41  5eb3d668b31de5d588f42933
# 42  5eb3d668b31de5d588f42933
#
#                                               address        borough  \
# 0   {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1   {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 2   {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 3   {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 4   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 5   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 6   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 7   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 8   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 9   {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# 10  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 11  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 12  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 13  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 14  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 15  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 16  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 17  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 18  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 19  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 20  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 21  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 22  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 23  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 24  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 25  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 26  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 27  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 28  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 29  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 30  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 31  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 32  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 33  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 34  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 35  {'building': '6409', 'coord': [-74.00528899999...       Brooklyn
# 36  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 37  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 38  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 39  {'building': '1839', 'coord': [-73.9482609, 40...       Brooklyn
# 40  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
# 41  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
# 42  {'building': '2300', 'coord': [-73.8786113, 40...          Bronx
#
#                             cuisine                         name  \
# 0                          American              Riviera Caterer
# 1                          American              Riviera Caterer
# 2                          American              Riviera Caterer
# 3                          American              Riviera Caterer
# 4                      Delicatessen           Wilken'S Fine Food
# 5                      Delicatessen           Wilken'S Fine Food
# 6                      Delicatessen           Wilken'S Fine Food
# 7                      Delicatessen           Wilken'S Fine Food
# 8                      Delicatessen           Wilken'S Fine Food
# 9                      Delicatessen           Wilken'S Fine Food
# 10                    Jewish/Kosher                Kosher Island
# 11                    Jewish/Kosher                Kosher Island
# 12                    Jewish/Kosher                Kosher Island
# 13                    Jewish/Kosher                Kosher Island
# 14                       Hamburgers                      Wendy'S
# 15                       Hamburgers                      Wendy'S
# 16                       Hamburgers                      Wendy'S
# 17                       Hamburgers                      Wendy'S
# 18                           Bakery        Morris Park Bake Shop
# 19                           Bakery        Morris Park Bake Shop
# 20                           Bakery        Morris Park Bake Shop
# 21                           Bakery        Morris Park Bake Shop
# 22                           Bakery        Morris Park Bake Shop
# 23                    Jewish/Kosher           Tov Kosher Kitchen
# 24                    Jewish/Kosher           Tov Kosher Kitchen
# 25                    Jewish/Kosher           Tov Kosher Kitchen
# 26                    Jewish/Kosher           Tov Kosher Kitchen
# 27                         American      Brunos On The Boulevard
# 28                         American      Brunos On The Boulevard
# 29                         American      Brunos On The Boulevard
# 30                         American      Brunos On The Boulevard
# 31                         American              Regina Caterers
# 32                         American              Regina Caterers
# 33                         American              Regina Caterers
# 34                         American              Regina Caterers
# 35                         American              Regina Caterers
# 36  Ice Cream, Gelato, Yogurt, Ices  Taste The Tropics Ice Cream
# 37  Ice Cream, Gelato, Yogurt, Ices  Taste The Tropics Ice Cream
# 38  Ice Cream, Gelato, Yogurt, Ices  Taste The Tropics Ice Cream
# 39  Ice Cream, Gelato, Yogurt, Ices  Taste The Tropics Ice Cream
# 40                         American                    Wild Asia
# 41                         American                    Wild Asia
# 42                         American                    Wild Asia
#
#    restaurant_id  index       date grade  score
# 0       40356018      0 2014-06-10     A      5
# 1       40356018      1 2013-06-05     A      7
# 2       40356018      2 2012-04-13     A     12
# 3       40356018      3 2011-10-12     A     12
# 4       40356483      0 2014-05-29     A     10
# 5       40356483      1 2014-01-14     A     10
# 6       40356483      2 2013-08-03     A      8
# 7       40356483      3 2012-07-18     A     10
# 8       40356483      4 2012-03-09     A     13
# 9       40356483      5 2011-10-14     A      9
# 10      40356442      0 2014-10-06     A      9
# 11      40356442      1 2014-05-20     A     12
# 12      40356442      2 2013-04-04     A     12
# 13      40356442      3 2012-01-24     A      9
# 14      30112340      0 2014-12-30     A      8
# 15      30112340      1 2014-07-01     B     23
# 16      30112340      2 2013-04-30     A     12
# 17      30112340      3 2012-05-08     A     12
# 18      30075445      0 2014-03-03     A      2
# 19      30075445      1 2013-09-11     A      6
# 20      30075445      2 2013-01-24     A     10
# 21      30075445      3 2011-11-23     A      9
# 22      30075445      4 2011-03-10     B     14
# 23      40356068      0 2014-11-24     Z     20
# 24      40356068      1 2013-01-17     A     13
# 25      40356068      2 2012-08-02     A     13
# 26      40356068      3 2011-12-15     B     25
# 27      40356151      0 2014-11-15     Z     38
# 28      40356151      1 2014-05-02     A     10
# 29      40356151      2 2013-03-02     A      7
# 30      40356151      3 2012-02-10     A     13
# 31      40356649      0 2014-07-18     A     12
# 32      40356649      1 2013-07-30     A     12
# 33      40356649      2 2013-02-13     A     11
# 34      40356649      3 2012-08-16     A      2
# 35      40356649      4 2011-08-17     A     11
# 36      40356731      0 2014-07-14     A     12
# 37      40356731      1 2013-07-10     A      8
# 38      40356731      2 2012-07-11     A      5
# 39      40356731      3 2012-02-23     A      8
# 40      40357217      0 2014-05-28     A     11
# 41      40357217      1 2013-06-19     A      4
# 42      40357217      2 2012-06-15     A      3
